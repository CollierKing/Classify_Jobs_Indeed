# %%
import sys
print(sys.version)
# Out:
# 3.6.0 |Continuum Analytics, Inc.| (default, Dec 23 2016, 11:57:41) [MSC v.1900 64 bit (AMD64)]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon

# %%
from geopy.geocoders import Nominatim
import math

# %%
plt.figure(figsize=(12,12))
plt.subplots_adjust(left=0.05,right=0.95,top=0.90,bottom=0.05,wspace=0.15,hspace=0.05)
axs = plt.subplot(111)

m = Basemap(
llcrnrlon = -119, llcrnrlat = 22, urcrnrlon = -64, 
urcrnrlat = 49, projection = 'lcc', lat_1 = 33, 
lat_2 = 45, lon_0 = -95)

map.readshapefile('st99_d00', name='states', drawbounds=True)

# m = Basemap(llcrnrlon = -119, llcrnrlat = 22, urcrnrlon = -64, 
# urcrnrlat = 49, projection = 'lcc', lat_1 = 33, 
# lat_2 = 45, lon_0 = -95, ax = axs)

# m.drawcountries(linewidth=0.5)
# m.drawcoastlines(linewidth=0.5)
m.fillcontinents(color="grey")
# m.drawmapboundary()

df = [{'lon': -90, 'lat': 38., 'site': 'point1'}, 
{'lon': -91.2, 'lat': 37.7, 'site': 'point2'},
     {'lon': -88., 'lat': 42., 'site': 'point2'}]

for point in df:
    x, y = m(point['lon'], point['lat'])
    axs.annotate(point['site'], xy=(x, y),  xycoords='data',
                xytext=(-40, 20), textcoords = 'offset points',
                arrowprops=dict(arrowstyle="->"))
    axs.plot(x, y, marker='o')

plt.show()

# %%
geolocator = Nominatim()
loc = geolocator.geocode("Rolling Rock, TX")

# %%
loc[1]
# Out:
# (32.871564, -96.69384)
